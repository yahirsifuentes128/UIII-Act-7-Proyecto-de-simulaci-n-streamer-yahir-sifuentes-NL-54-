# %% [markdown]
# <a href="https://colab.research.google.com/github/yahirsifuentes128/UIII-Act-7-Proyecto-de-simulaci-n-streamer-yahir-sifuentes-NL-54-/blob/main/UIII_Act_7_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_con_if%2C_else%2C_elif_while_tipo_Menu_yahir_sifuentes_NL_%3D_54_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### yahir sifuentes 20/mayo/2026
# #### UIII Act 7 Proyecto de simulación de inteligencia artificial con if, else, elif  while tipo Menu
# #### clase streamer y espectadores
# #### especialidad inteligencia aritficial

# %%
# =========================================
# STREAMER Y ESPECTADOR - IA SIMPLE
# CBTIS 128
# Alumno: Yahir Sifuentes Vargas
# =========================================

print("===================================")
print("   IA SIMPLE PARA STREAMERS")
print("===================================")

nombre = input("Ingresa tu nombre: ")

seguir = "si"

while seguir == "si":

    print("\nHola", nombre)
    print("\nMENU PRINCIPAL")
    print("1. Entrar como Streamer")
    print("2. Entrar como Espectador")
    print("3. Ver nivel de fama")
    print("4. Salir")

    opcion = input("Selecciona una opcion: ")

    # STREAMER
    if opcion == "1":

        viewers = int(input("¿Cuantos espectadores tienes?: "))

        if viewers >= 1000:
            print("🔥 Eres un streamer SUPER FAMOSO")
            print("La IA recomienda hacer un torneo en vivo")

        elif viewers >= 500:
            print("😎 Tu canal esta creciendo rapido")
            print("La IA recomienda subir clips a TikTok")

        elif viewers >= 100:
            print("🙂 Vas empezando pero tienes futuro")
            print("La IA recomienda interactuar con el chat")

        else:
            print("😅 Canal pequeño")
            print("La IA recomienda hacer directos mas seguido")

    # ESPECTADOR
    elif opcion == "2":

        horas = int(input("¿Cuantas horas ves streams al dia?: "))

        if horas >= 8:
            print("📺 Eres un espectador EXTREMO")
            print("La IA recomienda descansar un poco")

        elif horas >= 4:
            print("🎮 Te gustan mucho los streams")
            print("La IA recomienda seguir nuevos creadores")

        elif horas >= 1:
            print("👍 Eres espectador casual")
            print("La IA recomienda apoyar con un like")

        else:
            print("😴 Casi no ves streams")
            print("La IA recomienda explorar Twitch o YouTube")

    # NIVEL DE FAMA
    elif opcion == "3":

        seguidores = int(input("Ingresa tus seguidores: "))

        if seguidores >= 100000:
            print("🏆 Nivel LEYENDA DE INTERNET")

        elif seguidores >= 10000:
            print("⭐ Nivel STREAMER POPULAR")

        elif seguidores >= 1000:
            print("✨ Nivel CREADOR EN CRECIMIENTO")

        else:
            print("🌱 Nivel NOVATO")

    # SALIR
    elif opcion == "4":

        print("Gracias por usar la IA para streamers")
        seguir = "no"

    # OPCION INVALIDA
    else:
        print("❌ Opcion no valida")

print("Programa realizado por yahir sifuentes ")
# Out:
# ...
#    IA SIMPLE PARA STREAMERS
# ...
# Ingresa tu nombre: el rubius
#
# Hola el rubius
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 1
# ¿Cuantos espectadores tienes?: 10000
# 🔥 Eres un streamer SUPER FAMOSO
# La IA recomienda hacer un torneo en vivo
#
# Hola el rubius
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 2
# ¿Cuantas horas ves streams al dia?: 2
# 👍 Eres espectador casual
# La IA recomienda apoyar con un like
#
# Hola el rubius
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 3
# Ingresa tus seguidores: 10000
# ⭐ Nivel STREAMER POPULAR
#
# Hola el rubius
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 4
# Gracias por usar la IA para streamers
# ...

# %%
# =========================================
# STREAMER Y ESPECTADOR - IA SIMPLE
# CBTIS 128
# Alumno: Yahir Sifuentes Vargas
# =========================================

print("===================================")
print("   IA SIMPLE PARA STREAMERS")
print("===================================")

nombre = input("Ingresa tu nombre: ")

seguir = "si"

while seguir == "si":

    print("\nHola", nombre)
    print("\nMENU PRINCIPAL")
    print("1. Entrar como Streamer")
    print("2. Entrar como Espectador")
    print("3. Ver nivel de fama")
    print("4. Salir")

    opcion = input("Selecciona una opcion: ")

    # STREAMER
    if opcion == "1":

        viewers = int(input("¿Cuantos espectadores tienes?: "))

        if viewers >= 1000:
            print("🔥 Eres un streamer SUPER FAMOSO")
            print("La IA recomienda hacer un torneo en vivo")

        elif viewers >= 500:
            print("😎 Tu canal esta creciendo rapido")
            print("La IA recomienda subir clips a TikTok")

        elif viewers >= 100:
            print("🙂 Vas empezando pero tienes futuro")
            print("La IA recomienda interactuar con el chat")

        else:
            print("😅 Canal pequeño")
            print("La IA recomienda hacer directos mas seguido")

    # ESPECTADOR
    elif opcion == "2":

        horas = int(input("¿Cuantas horas ves streams al dia?: "))

        if horas >= 8:
            print("📺 Eres un espectador EXTREMO")
            print("La IA recomienda descansar un poco")

        elif horas >= 4:
            print("🎮 Te gustan mucho los streams")
            print("La IA recomienda seguir nuevos creadores")

        elif horas >= 1:
            print("👍 Eres espectador casual")
            print("La IA recomienda apoyar con un like")

        else:
            print("😴 Casi no ves streams")
            print("La IA recomienda explorar Twitch o YouTube")

    # NIVEL DE FAMA
    elif opcion == "3":

        seguidores = int(input("Ingresa tus seguidores: "))

        if seguidores >= 100000:
            print("🏆 Nivel LEYENDA DE INTERNET")

        elif seguidores >= 10000:
            print("⭐ Nivel STREAMER POPULAR")

        elif seguidores >= 1000:
            print("✨ Nivel CREADOR EN CRECIMIENTO")

        else:
            print("🌱 Nivel NOVATO")

    # SALIR
    elif opcion == "4":

        print("Gracias por usar la IA para streamers")
        seguir = "no"

    # OPCION INVALIDA
    else:
        print("❌ Opcion no valida")

print("Programa realizado por yahir sifuentes ")
# Out:
# ...
#    IA SIMPLE PARA STREAMERS
# ...
# Ingresa tu nombre: juan
#
# Hola juan
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 1
# ¿Cuantos espectadores tienes?: 50
# 😅 Canal pequeño
# La IA recomienda hacer directos mas seguido
#
# Hola juan
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 2
# ¿Cuantas horas ves streams al dia?: 8
# 📺 Eres un espectador EXTREMO
# La IA recomienda descansar un poco
#
# Hola juan
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 3
# Ingresa tus seguidores: 25
# 🌱 Nivel NOVATO
#
# Hola juan
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 4
# Gracias por usar la IA para streamers
# Programa realizado por yahir sifuentes

# %%
# =========================================
# STREAMER Y ESPECTADOR - IA SIMPLE
# CBTIS 128
# Alumno: Yahir Sifuentes Vargas
# =========================================

print("===================================")
print("   IA SIMPLE PARA STREAMERS")
print("===================================")

nombre = input("Ingresa tu nombre: ")

seguir = "si"

while seguir == "si":

    print("\nHola", nombre)
    print("\nMENU PRINCIPAL")
    print("1. Entrar como Streamer")
    print("2. Entrar como Espectador")
    print("3. Ver nivel de fama")
    print("4. Salir")

    opcion = input("Selecciona una opcion: ")

    # STREAMER
    if opcion == "1":

        viewers = int(input("¿Cuantos espectadores tienes?: "))

        if viewers >= 1000:
            print("🔥 Eres un streamer SUPER FAMOSO")
            print("La IA recomienda hacer un torneo en vivo")

        elif viewers >= 500:
            print("😎 Tu canal esta creciendo rapido")
            print("La IA recomienda subir clips a TikTok")

        elif viewers >= 100:
            print("🙂 Vas empezando pero tienes futuro")
            print("La IA recomienda interactuar con el chat")

        else:
            print("😅 Canal pequeño")
            print("La IA recomienda hacer directos mas seguido")

    # ESPECTADOR
    elif opcion == "2":

        horas = int(input("¿Cuantas horas ves streams al dia?: "))

        if horas >= 8:
            print("📺 Eres un espectador EXTREMO")
            print("La IA recomienda descansar un poco")

        elif horas >= 4:
            print("🎮 Te gustan mucho los streams")
            print("La IA recomienda seguir nuevos creadores")

        elif horas >= 1:
            print("👍 Eres espectador casual")
            print("La IA recomienda apoyar con un like")

        else:
            print("😴 Casi no ves streams")
            print("La IA recomienda explorar Twitch o YouTube")

    # NIVEL DE FAMA
    elif opcion == "3":

        seguidores = int(input("Ingresa tus seguidores: "))

        if seguidores >= 100000:
            print("🏆 Nivel LEYENDA DE INTERNET")

        elif seguidores >= 10000:
            print("⭐ Nivel STREAMER POPULAR")

        elif seguidores >= 1000:
            print("✨ Nivel CREADOR EN CRECIMIENTO")

        else:
            print("🌱 Nivel NOVATO")

    # SALIR
    elif opcion == "4":

        print("Gracias por usar la IA para streamers")
        seguir = "no"

    # OPCION INVALIDA
    else:
        print("❌ Opcion no valida")

print("Programa realizado por yahir sifuentes ")
# Out:
# ...
#    IA SIMPLE PARA STREAMERS
# ...
# Ingresa tu nombre: alexcrashers
#
# Hola alexcrashers
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 1
# ¿Cuantos espectadores tienes?: 5000
# 🔥 Eres un streamer SUPER FAMOSO
# La IA recomienda hacer un torneo en vivo
#
# Hola alexcrashers
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 2
# ¿Cuantas horas ves streams al dia?: 4
# 🎮 Te gustan mucho los streams
# La IA recomienda seguir nuevos creadores
#
# Hola alexcrashers
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 3
# Ingresa tus seguidores: 1200
# ✨ Nivel CREADOR EN CRECIMIENTO
#
# Hola alexcrashers
#
# MENU PRINCIPAL
# 1. Entrar como Streamer
# 2. Entrar como Espectador
# 3. Ver nivel de fama
# 4. Salir
# Selecciona una opcion: 4
# ...

# %% [markdown]
#  ![](https://raw.githubusercontent.com/yahirsifuentes128/UIII-Act-7-Proyecto-de-simulaci-n-streamer-yahir-sifuentes-NL-54-/refs/heads/main/infografia%20clase%20streamer%20y%20espectador%20(2).png)
